# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhayNath001/CodeClause_Sales_Analysis/blob/main/CodeClause(Abhay_Nath).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

#------------this is my sample data-----------------
sales_data = pd.read_csv('Sales_April_2019.csv')

sales_data['Price Each'] = pd.to_numeric(sales_data['Price Each'], errors='coerce')
sales_data['Quantity Ordered'] = pd.to_numeric(sales_data['Quantity Ordered'], errors='coerce')

#---------------------here I calculate the total sales---------------
total_sales = (sales_data['Price Each'] * sales_data['Quantity Ordered']).sum()

#----------------------here I calculate the average price------------------------------------
average_price = sales_data['Price Each'].mean()

#----------------------Now calculate the total quantity ordered-------------------------------
total_quantity = sales_data['Quantity Ordered'].sum()

#-------------------------Calculate sales by product------------------------------
product_sales = sales_data.groupby('Product')['Price Each'].sum()

product_sales.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Product')
plt.ylabel('Sales')
plt.title('Sales by Product')
plt.show()

print(f'Total Sales: ${total_sales:.2f}')
print(f'Average Price: ${average_price:.2f}')
print(f'Total Quantity Ordered: {total_quantity}')
print('\nProduct Sales:')
print(product_sales)
# Out:
# Total Sales: $3396059.11
# Average Price: $184.43
# Total Quantity Ordered: 20568.0
#
# Product Sales:
# Product
# 20in Monitor                   42896.10
# 27in 4K Gaming Monitor        219564.37
# 27in FHD Monitor              110092.66
# 34in Ultrawide Monitor        246993.50
# AA Batteries (4-pack)           7921.92
# AAA Batteries (4-pack)          5947.11
# Apple Airpods Headphones      227250.00
# Bose SoundSport Headphones    127987.20
# Flatscreen TV                 137400.00
# Google Phone                  348600.00
# LG Dryer                       46200.00
# LG Washing Machine             36600.00
# Lightning Charging Cable       32904.95
# Macbook Pro Laptop            770100.00
# Product                            0.00
# ThinkPad Laptop               391996.08
# USB-C Charging Cable           24844.05
# Vareebadd Phone                88000.00
# Wired Headphones               22661.10
# iPhone                        485100.00
# Name: Price Each, dtype: float64
